# %%
# !git clone https://github.com/oopir/cld_optimization_experiments
# %cd cld_optimization_experiments

# %%
# from src.expr1 import run as run_expr1
# run_expr1(100)

# %%
# from src.expr2 import run as run_expr2
# run_expr2(100)
